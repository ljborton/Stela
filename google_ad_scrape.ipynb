# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

import os
chromedriver = "/Users/laura.borton/Documents/python_stuff/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

driver = webdriver.Chrome(chromedriver)

# %%
driver.get("https://ads.google.com/aw/universal/assets?campaignId=1695060374&ocid=300159734&__c=1062484166&authuser=0&__u=9819492084")

# %% [markdown]
# LOGIN

# %%
x = 20

# %%
asset = []
for i in range (2,x):
    
    job_xpath= '//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[2]/app-asset-preview'.format(i)
    job= driver.find_element_by_xpath(job_xpath).text 
    asset.append(job)

# %%
asset_type = []
for i in range (2,x):
    job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[4]'.format(i)
    job= driver.find_element_by_xpath(job_xpath).text 
    asset_type.append(job)

# %%
impr = []
for i in range (2,x):
    job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[5]'.format(i)
    job= driver.find_element_by_xpath(job_xpath).text 
    impr.append(job)

# %%
clicks = []
for i in range (2,x):
    job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[6]'.format(i)
    job= driver.find_element_by_xpath(job_xpath).text 
    clicks.append(job)

# %%
cost = []
for i in range (2,x):
    job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[7]'.format(i)
    job= driver.find_element_by_xpath(job_xpath).text 
    cost.append(job)

# %%
ctr = []
for i in range (2,x):
    job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[8]'.format(i)
    job= driver.find_element_by_xpath(job_xpath).text 
    ctr.append(job)

# %%
cpc = []
for i in range (2,x):
    job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[9]'.format(i)
    job= driver.find_element_by_xpath(job_xpath).text 
    cpc.append(job)

# %%
conv = []
for i in range (2,x):
    job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[10]'.format(i)
    job= driver.find_element_by_xpath(job_xpath).text 
    conv.append(job)

# %%
all_conv = []
for i in range (2,x):
    job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[11]'.format(i)
    job= driver.find_element_by_xpath(job_xpath).text 
    all_conv.append(job)

# %%
Lumi_Stela_UAC_Android_CPA = pd.DataFrame(
    {'Asset': asset, 'Asset_type': asset_type, 'Impr': impr, 'Clicks': clicks, 'Cost':cost, 
     'CTR' : ctr, 'CPC': cpc, 'Conv': conv, 'All_conv': all_conv})

# %%
y = 156
gpp = []
for i in range (2,y):
    job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[{}]/ess-cell[2]'.format(i)
#if driver.find_element_by_xpath(job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[3]/ess-cell[2]').text = 'Google Play Purchase':
    job = driver.find_element_by_xpath(job_xpath).text
    gpp.append(job)

    
if gpp = 'Google Play Purchase':
    

#    gpp = driver.find_element_by_xpath(job_xpath='//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[3]/ess-cell[11]').text
 #   if job_xpath = 'Google Play Purchase':
#job= driver.find_element_by_xpath(job_xpath).text
#gpp.append(job)
   # else:
# //*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[12]/ess-cell[2]/text-field/text()       
#gpp

# %%
gpp
#//*[@id="cmExtensionPoint-id"]/base-root/div/div[2]/div[1]/view-loader/universal-app-campaign-asset-view/div/tableview/div[6]/ess-table/ess-particle-table/div[1]/div/div[2]/div[155]/ess-cell[2]/text-field/text()
# Out:
# ['1200x628_top20Untold Love_ Alyan and the Lamp.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  'Lumi_Artboard 4_1.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  'Text idea: Graphic Novel on the Go',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  '1200x628_notext.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  'Untold Love: Lumi White_Discovered\nby Stela - Graphic Novel & mBooks',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  '1200x628_top20The Picture of Dorian Gray.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  'Lumi_Artboard 2_1.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  'Text idea: No.1 Trending Comic App',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  '1200x628_top20Princess and the Frog.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  'Text idea: Read Premium Comics.',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  '1200x628_top20Grimms_ Fairy Tales.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  '1200x628_top20Untold Love_ Lumi White.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  '1200x628_top20Afrina and the Glass Coffin.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  '1200x628_top20Rapunzel.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  '1200x628_top20Irish Fairy Tales.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  'Untold Love: Lumi White _ The Broken Glass\nby Stela - Graphic Novel & mBooks',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  '1200x628_top20breaker.jpg\n1200 X 628 jpg',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished',
#  'Text idea: Top 5 Graphic Novel App',
#  'Google Play Purchase',
#  'Stela - Premium mBook, Comics, and Manga (Android) first_open',
#  'Stela - Premium mBook, Comics, and Manga (Android) installs',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_loginview_FAQ',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_privacy',
#  'Stela - Premium mBook, Comics, and Manga (Android) opened_subscribe_view_subscription_info',
#  'Stela - Premium mBook, Comics, and Manga (Android) session_start',
#  'Stela - Premium mBook, Comics, and Manga (Android) tutorial_finished']

# %%
Lumi_Stela_UAC_Android_CPA
# Out:
#                                                 Asset Asset_type       Impr  \
# 0   Untold Love: Lumi White_Discovered\nby Stela -...      Video    140,732
# 1                 1200x628_notext.jpg\n1200 X 628 jpg      Image  9,572,056
# 2                  Text idea: Graphic Novel on the Go  Text idea    310,824
# 3               Lumi_Artboard 4_1.jpg\n1200 X 628 jpg      Image  4,144,414
# 4   1200x628_top20Untold Love_ Alyan and the Lamp....      Image  7,352,513
# 5   1200x628_top20Afrina and the Glass Coffin.jpg\...      Image  1,455,279
# 6   1200x628_top20Untold Love_ Lumi White.jpg\n120...      Image    812,694
# 7   1200x628_top20Grimms_ Fairy Tales.jpg\n1200 X ...      Image  1,351,391
# 8                     Text idea: Read Premium Comics.  Text idea    245,927
# 9   1200x628_top20Princess and the Frog.jpg\n1200 ...      Image    910,004
# 10                 Text idea: No.1 Trending Comic App  Text idea    314,011
# 11              Lumi_Artboard 2_1.jpg\n1200 X 628 jpg      Image  1,018,253
# 12  1200x628_top20The Picture of Dorian Gray.jpg\n...      Image  2,060,299
# 13                 Text idea: Top 5 Graphic Novel App  Text idea    220,061
# 14          1200x628_top20breaker.jpg\n1200 X 628 jpg      Image    118,191
# 15  Untold Love: Lumi White _ The Broken Glass\nby...      Video     80,659
# 16  1200x628_top20Irish Fairy Tales.jpg\n1200 X 62...      Image    287,091
# 17         1200x628_top20Rapunzel.jpg\n1200 X 628 jpg      Image    577,286
#
#     Clicks       Cost    CTR    CPC      Conv   All_conv
# 0      313    $539.35  0.22%  $1.72     96.00     362.00
# 1   57,478  $7,900.30  0.60%  $0.14  3,089.00  11,346.00
# 2    6,332  $6,385.99  2.04%  $1.01  1,206.00   4,229.00
# 3    8,844  $2,517.76  0.21%  $0.28    570.00   2,331.00
# 4   14,689  $4,388.27  0.20%  $0.30  1,160.00   4,499.00
# 5    3,373    $969.41  0.23%  $0.29    255.00     970.00
# 6    1,624    $635.49  0.20%  $0.39     81.00     321.00
# 7    2,739    $969.00  0.20%  $0.35    181.00     687.00
# 8    4,398  $3,069.63  1.79%  $0.70    541.00   1,909.00
# 9    2,088    $688.74  0.23%  $0.33    107.00     386.00
# 10   6,275  $6,354.61  2.00%  $1.01  1,177.00   4,120.00
# 11   2,082    $785.31  0.20%  $0.38    138.00     543.00
# 12   4,305  $1,368.30  0.21%  $0.32    318.00   1,260.00
# 13   4,519  $3,082.90  2.05%  $0.68    544.00   1,942.00
# 14     360    $177.03  0.30%  $0.49     24.00      92.00
# 15     176    $323.46  0.22%  $1.84     43.00     169.00
# 16     504    $213.01  0.18%  $0.42     18.00      67.00
# 17   1,101    $442.83  0.19%  $0.40     61.00     213.00

# %%
Lumi_Stela_UAC_Android_CPA.to_csv('Lumi_Stela_UAC_Android_CPA.csv')

# %%
clicks
# Out:
# ['313',
#  '57,478',
#  '6,332',
#  '8,844',
#  '14,689',
#  '3,373',
#  '1,624',
#  '2,739',
#  '4,398',
#  '2,088',
#  '6,275',
#  '2,082',
#  '4,305',
#  '4,519',
#  '360',
#  '176',
#  '504',
#  '1,101']

# %%
driver.close()
